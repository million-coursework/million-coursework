# %%
email = """

Hi Steve,

I hope you're well. I was wondering if I could have a permission code for your course COMP1140. 
Last semester, I completed COMP1100, but for some reason i cant enrol.

Thanks!

Tom

"""

!~/downloads/google-cloud-sdk/bin/gcloud beta auth application-default login

# !gcloud beta auth application-default login
# Out:
# Your browser has been opened to visit:
#
#     https://accounts.google.com/o/oauth2/auth?redirect_uri=http%3A%2F%2Flocalhost%3A8085%2F&prompt=select_account&response_type=code&client_id=764086051850-6qr4p6gpi6hn506pt8ejuq83di341hur.apps.googleusercontent.com&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fuserinfo.email+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcloud-platform&access_type=offline
#
#
#
# Credentials saved to file: [/Users/Tom/.config/gcloud/application_default_credentials.json]
#
# These credentials will be used by any library that requests
# Application Default Credentials.
#
# To generate an access token for other uses, run:
#   gcloud auth application-default print-access-token

# %%
!~/downloads/google-cloud-sdk/bin/gcloud auth application-default print-access-token
# Out:
# ya29.GlsCBjeRWh4TOqkqGj0R5ykzQrnoq_FYTC3nTCsJqWk8G1iqC__cuiOQRiVWsW3L3LuVT2t4fuld31sC81zx0OGre_w5aTgiAl29ZC6Ug2t5meHpciSrayiPnOSQ

# %%
import pandas as pd
import requests


course_codes = list(pd.read_csv("All_courses.csv")['\n                    Code\n                '])
course_names = list(pd.read_csv("All_courses.csv")['\n                    Title\n                '])

payload = []
YEARS = range(2018,2020)
for year in YEARS:
    for course in zip(course_codes,course_names):
        print(("\""+course[0]+"\","+"\""+course[0]+"\","+"\""+course[1]+"\"").replace('(',"").replace(')',""))
# Out:
# "ENGL6020","ENGL6020","16th, 17th and 18th  Century Literature"
# "ENGL3005","ENGL3005","16th, 17th and 18th Century LiteratureH"
# "PREP1102","PREP1102","20th Century History"
# "MGMT7169","MGMT7169","A Management Framework For Business Projects"
# "ASIA2107","ASIA2107","ACICIS International Relations Program"
# "ASIA2107","ASIA2107","ACICIS International Relations Program"
# "CBEA6070","CBEA6070","ANU College of Business and Economics Internship Project PG"
# "CBEA6070","CBEA6070","ANU College of Business and Economics Internship Project PG"
# "CBEA3070","CBEA3070","ANU College of Business and Economics Internship Project UG"
# "CBEA3070","CBEA3070","ANU College of Business and Economics Internship Project UG"
# "EXTN1001A","EXTN1001A","ANU Extension Astrophysics A"
# "EXTN1001B","EXTN1001B","ANU Extension Astrophysics B"
# "EXTN1002A","EXTN1002A","ANU Extension Chemistry A"
# "EXTN1002B","EXTN1002B","ANU Extension Chemistry B"
# ...

# %%
import requests
url = 'https://dialogflow.googleapis.com/v2beta1/{parent=projects/*/agent/entityTypes/*}/entities:batchCreate'
payload = str(payload) 
#print(payload)

# GET
headers = {"Authorization":"Bearer c03d870afdb346fc9d2c81b27da32ce4"}

# POST with JSON 
import json
r = requests.post(url,headers=headers, data=json.dumps(payload))

# Response, status etc
r.text
r.status_code
# Out:
# 404

# %%
import json

# %%
url = 'https://dialogflow.googleapis.com/v2beta1/projects/my-gcp-project-id/knowledgeBases/my-knowledge-base-id/documents'

# %%
def call_dialogflow(s):
    url = 'https://dialogflow.googleapis.com/v2beta1/projects/anu-tier-1-and-0/agent/sessions/c8dfbce5-7fda-b1e8-5758-6509c4740c2b:detectIntent'
    payload = """{
        "queryInput":{
            "text":{
                "text":%s,
                "languageCode":"en"
                }
            },
        "queryParams":{
            "timeZone":"Australia/Sydney"
        }
    }""" % s
    headers = {
               'Authorization': 'Bearer ya29.c.EloEBrsT2vQ3EdNEhKCTMXV9qCNY73DaE5L_Ta-GlfPCRhbcG_Ses63usufFUT4E0KLaBmttdoXZzMDirDXToI5SZu6jsu0NQQC7pO9yYoVURFxFZhvRxvvckZA'
              }

    return requests.post(url, data=payload, headers=headers)

# %%
call_dialogflow("\"I need a permission code for COMP3120\"").text
# Out:
# '{\n  "error": {\n    "code": 400,\n    "message": "Invalid JSON payload received. Unexpected token.\\n             \\"text\\":I hope you\'re well. \\n                    ^",\n    "status": "INVALID_ARGUMENT"\n  }\n}\n'

# %%
flatten = lambda l: [item for sublist in l for item in sublist]

def analyse_sentence(sentence):
    res = call_dialogflow("\""+sentence+"\"").json()['queryResult']
    print(res)
    intent, parameters = res['intent'], res['parameters']
    print(intent)
    print(parameters)
    

for sentence in email.split('.'):
    print(sentence)
    analyse_sentence(sentence)
# Out:
# Hi Steve,
#
# I hope you're well
# ...

# %%
# Out:
# {'alternativeQueryResults': [{'languageCode': 'en',
#    'queryText': 'I need a permission code for COMP3120'}],
#  'queryResult': {'allRequiredParamsPresent': True,
#   'fulfillmentMessages': [{'text': {'text': ['']}}],
#   'intent': {'displayName': 'Need Permission Code',
#    'name': 'projects/anu-tier-1-and-0/agent/intents/63cabcd3-b95d-4760-81d8-4707e5132339'},
#   'intentDetectionConfidence': 1,
#   'languageCode': 'en',
#   'parameters': {'CourseCode': 'COMP3120'},
#   'queryText': 'I need a permission code for COMP3120'},
#  'responseId': 'f3274d54-30ed-4838-9439-f4e753e64628'}
